# %%
# !pip install transformers
from transformers import AutoModelForMaskedLM
from transformers import AutoTokenizer
from transformers import pipeline

# %%
tokenizer = AutoTokenizer.from_pretrained("aubmindlab/bert-base-arabertv02")
model = AutoModelForMaskedLM.from_pretrained("aubmindlab/bert-base-arabertv02")
# Out:
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv02 were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
fill_mask = pipeline(
    "fill-mask",
    model="aubmindlab/bert-base-arabertv02",
    tokenizer="aubmindlab/bert-base-arabertv02"
)
# Out:
# Some weights of the model checkpoint at aubmindlab/bert-base-arabertv02 were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
fill_mask(" تقع الجامعة [MASK] في عمان ")
# Out:
# [{'score': 0.7218064069747925,
#   'sequence': 'تقع الجامعة الأردنية في عمان',
#   'token': 9005,
#   'token_str': 'الأردنية'},
#  {'score': 0.07981135696172714,
#   'sequence': 'تقع الجامعة الاردنية في عمان',
#   'token': 15345,
#   'token_str': 'الاردنية'},
#  {'score': 0.06322503089904785,
#   'sequence': 'تقع الجامعة الهاشمية في عمان',
#   'token': 31863,
#   'token_str': 'الهاشمية'},
#  {'score': 0.023768609389662743,
#   'sequence': 'تقع الجامعة الأميركية في عمان',
#   'token': 2357,
#   'token_str': 'الأميركية'},
#  {'score': 0.015922239050269127,
#   'sequence': 'تقع الجامعة العربية في عمان',
#   'token': 773,
#   'token_str': 'العربية'}]
